# %%
import pandas as pd
import numpy as np
import os

os.getcwd()
os.listdir()
df = pd.read_csv("artists.csv")
df.columns = df.columns.str.strip().str.lower().str.replace(" ","_") #strip for remove white space(column name)
df.columns
# Out:
# Index(['artist_id', 'name', 'followers', 'popularity', 'genres', 'main_genre'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5015 entries, 0 to 5014
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   artist_id   5015 non-null   object
#  1   name        5015 non-null   object
#  2   followers   5015 non-null   int64
#  3   popularity  5015 non-null   int64
#  4   genres      5015 non-null   object
#  5   main_genre  4963 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 156.8+ KB
# None

# %%
 # remove white space in object data type column
for i in df.select_dtypes(include = ["object"]).columns:
  df[i] = df[i].astype(str).str.strip()

df
# Out:
#                    artist_id                name  followers  popularity  \
# 0     6Cqtx9fpxzggIMuKn0RGCp      Dream Supplier      13878          85
# 1     2YZyLoL8N0Wb9xBt1NhZWg      Kendrick Lamar   45674032          91
# 2     250b0Wlc5Vk0CoUsaCY84M              JENNIE   13013134          83
# 3     6zO1dZ40fTZ5hY9NnnRJSk            yung kai    2117767          71
# 4     4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator   25263506          88
# ...                      ...                 ...        ...         ...
# 5010  2Hjj68yyUPiC0HKEOigcEp     Jesse McCartney    1064222          60
# 5011  1frmN1C7BmO6wKo7iQhar2          Kai Swervo      15553          46
# 5012  0XNKQFs2Ewb3y0VsFUFc5l        MORGENSHTERN    2578347          63
# 5013  3KJigfhLjMfuE2HXsgXbln                中島健人      46650          56
# 5014  6DDTbUgrNrVcAJFVrOjmVK   Diomedes Chinaski     148861          55
#
#                                                  genres  \
# 0     sleep, white noise, rain, binaural, lullaby, c...
# 1                           hip hop, west coast hip hop
# 2                                                 k-pop
# 3     k-pop, nyc pop, sped up, chill r&b, gen z sing...
# 4                                          hip hop, rap
# ...                                                 ...
# 5010                      dance pop, pop, post-teen pop
# 5011                              new york drill, drill
# 5012                      russian hip hop, russian trap
# 5013                                       anime, j-pop
# 5014                                  brazilian hip hop
#
#                                      main_genre
# 0     Easy Listening, Electronic, New Age, Rock
# 1                                       Hip Hop
# 2                                           Pop
# 3                    Electronic, Pop, R&B, Rock
# 4                                       Hip Hop
# ...                                         ...
# 5010                                        Pop
# 5011                                    Hip Hop
# 5012                                    Hip Hop
# 5013                                        Pop
# 5014                                    Hip Hop
#
# [5015 rows x 6 columns]

# %%
print(df.isnull().sum())
# Out:
# artist_id     0
# name          0
# followers     0
# popularity    0
# genres        0
# main_genre    0
# dtype: int64

# %%
# hanfling missing value
# if numeric valur then fill it with median and if categorical data then fill it with mode 

for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        df[col].fillna(df[col].median())
    elif pd.api.types.is_datetime64_any_dtype(df[col]):
        df[col].fillna(df[col].mode())
    elif pd.api.types.is_object_dtype(df[col]):
        df[col].fillna(df[col].mode())
    else:
        df[col].fillna(df[col].ffill())

df
# Out:
#                    artist_id                name  followers  popularity  \
# 0     6Cqtx9fpxzggIMuKn0RGCp      Dream Supplier      13878          85
# 1     2YZyLoL8N0Wb9xBt1NhZWg      Kendrick Lamar   45674032          91
# 2     250b0Wlc5Vk0CoUsaCY84M              JENNIE   13013134          83
# 3     6zO1dZ40fTZ5hY9NnnRJSk            yung kai    2117767          71
# 4     4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator   25263506          88
# ...                      ...                 ...        ...         ...
# 5010  2Hjj68yyUPiC0HKEOigcEp     Jesse McCartney    1064222          60
# 5011  1frmN1C7BmO6wKo7iQhar2          Kai Swervo      15553          46
# 5012  0XNKQFs2Ewb3y0VsFUFc5l        MORGENSHTERN    2578347          63
# 5013  3KJigfhLjMfuE2HXsgXbln                中島健人      46650          56
# 5014  6DDTbUgrNrVcAJFVrOjmVK   Diomedes Chinaski     148861          55
#
#                                                  genres  \
# 0     sleep, white noise, rain, binaural, lullaby, c...
# 1                           hip hop, west coast hip hop
# 2                                                 k-pop
# 3     k-pop, nyc pop, sped up, chill r&b, gen z sing...
# 4                                          hip hop, rap
# ...                                                 ...
# 5010                      dance pop, pop, post-teen pop
# 5011                              new york drill, drill
# 5012                      russian hip hop, russian trap
# 5013                                       anime, j-pop
# 5014                                  brazilian hip hop
#
#                                      main_genre
# 0     Easy Listening, Electronic, New Age, Rock
# 1                                       Hip Hop
# 2                                           Pop
# 3                    Electronic, Pop, R&B, Rock
# 4                                       Hip Hop
# ...                                         ...
# 5010                                        Pop
# 5011                                    Hip Hop
# 5012                                    Hip Hop
# 5013                                        Pop
# 5014                                    Hip Hop
#
# [5015 rows x 6 columns]

# %%
# remove duplicates
len(df)
df.drop_duplicates()
len(df)
# Out:
# 5015

# %%
df.to_csv("artists.csv")
